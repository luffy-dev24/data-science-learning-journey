# %%
# variables are containers used to store values

# %%
a = 5

# %%
b = 6

# %%
print(a+b)
# Out:
# 11

# %%
# in python variables are dynamic typed means we don't need to declare type

# %%
number = 33  #integer

# %%
name = "luffy" #string

# %%
price = 3.0  #float

# %%
is_boolean = True  #boolean

# %%
list_data_type = [1,2,3,4,5] #list

# %%
tuple_data_type = (1,2,3) #tuple

# %%
dict_data_type = {"name":"luffy"} #dictionary

# %%
 #type casting

# %%
a = "333"

# %%
a = int(a) #type casting

# %%
print(type(a))
# Out:
# <class 'int'>
