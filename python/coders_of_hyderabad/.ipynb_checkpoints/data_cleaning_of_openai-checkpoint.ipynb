# %%
import json

def load_json_data(filename):
    with open(filename,"r") as f:
        data= f.read()
    return data

# %%
initial_data = load_json_data("openai_instagram_followers.txt")
chunks = initial_data.split("\n")

# %%
def parse_chunk(chunk):
    sep_chunk = chunk.split("|")
    username = sep_chunk[0]
    no_of_posts = sep_chunk[1]
    no_of_followers = sep_chunk[2]
    no_of_followings = sep_chunk[3]
    category = sep_chunk[4]
    bio = sep_chunk[5]

    parsed_chunk = {"username":username,"no_of_posts":no_of_posts,"no_of_followers":no_of_followers,
                    "no_of_followings":no_of_followings,"category":category,"bio":bio}
    return parsed_chunk

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
all_chunks
# Out:
# [{'username': 'name',
#   'no_of_posts': 'posts',
#   'no_of_followers': 'followers',
#   'no_of_followings': 'following',
#   'category': 'category',
#   'bio': 'bio'},
#  {'username': 'Sam Altman',
#   'no_of_posts': '312',
#   'no_of_followers': '1200000',
#   'no_of_followings': '480',
#   'category': 'Person of public figure',
#   'bio': 'CEO of OpenAI, building safe and beneficial AI'},
#  {'username': 'Greg Brockman',
#   'no_of_posts': '198',
#   'no_of_followers': '430000',
#   'no_of_followings': '310',
#   'category': 'Person of public figure',
#   'bio': 'President at OpenAI, co-founder'},
#  {'username': 'Ilya Sutskever',
#   'no_of_posts': '45',
#   'no_of_followers': '980000',
#   'no_of_followings': '120',
#   'category': 'Scientist',
#   'bio': 'Co-founder & Chief Scientist at OpenAI'},
#  {'username': 'Karol Hausman',
#   'no_of_posts': '87',
#   'no_of_followers': '52000',
#   'no_of_followings': '340',
#   'category': 'Scientist',
#   'bio': 'Research scientist at Google DeepMind'},
#  {'username': 'Andrew Ng',
#   'no_of_posts': '520',
#   'no_of_followers': '3100000',
#   'no_of_followings': '890',
#   'category': 'Education',
#   'bio': 'Co-founder of Coursera, DeepLearning.AI, Stanford prof'},
#  {'username': 'Yann LeCun',
#   'no_of_posts': '634',
#   'no_of_followers': '780000',
#   'no_of_followings': '1200',
#   'category': 'Scientist',
#   'bio': 'Chief AI Scientist at Meta, Turing Award winner'},
#  {'username': 'Geoffrey Hinton',
#   'no_of_posts': '23',
#   'no_of_followers': '650000',
#   'no_of_followings': '90',
#   'category': 'Scientist',
#   'bio': 'Godfather of deep learning, Nobel Prize winner'},
#  {'username': 'Demis Hassabis',
#   'no_of_posts': '156',
#   'no_of_followers': '920000',
#   'no_of_followings': '270',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Google DeepMind, Nobel Prize winner'},
#  {'username': 'Max Tegmark',
#   'no_of_posts': '210',
#   'no_of_followers': '340000',
#   'no_of_followings': '560',
#   'category': 'Scientist',
#   'bio': 'MIT professor, AI safety researcher, Future of Life Institute'},
#  {'username': 'Lex Fridman',
#   'no_of_posts': '890',
#   'no_of_followers': '4200000',
#   'no_of_followings': '1100',
#   'category': 'Digital creator',
#   'bio': 'AI researcher & podcaster at MIT'},
#  {'username': 'Andrej Karpathy',
#   'no_of_posts': '143',
#   'no_of_followers': '1500000',
#   'no_of_followings': '420',
#   'category': 'Digital creator',
#   'bio': 'Former Tesla AI director, ex-OpenAI, educator'},
#  {'username': 'Gary Marcus',
#   'no_of_posts': '467',
#   'no_of_followers': '230000',
#   'no_of_followings': '980',
#   'category': 'Scientist',
#   'bio': 'NYU professor, AI critic and author'},
#  {'username': 'AI Explained',
#   'no_of_posts': '267',
#   'no_of_followers': '890000',
#   'no_of_followings': '320',
#   'category': 'Digital creator',
#   'bio': 'Breaking down AI research for everyone'},
#  {'username': 'MIT CSAIL',
#   'no_of_posts': '1230',
#   'no_of_followers': '510000',
#   'no_of_followings': '890',
#   'category': 'Education',
#   'bio': "MIT's Computer Science and Artificial Intelligence Lab"},
#  {'username': 'Stanford HAI',
#   'no_of_posts': '876',
#   'no_of_followers': '380000',
#   'no_of_followings': '560',
#   'category': 'Non-profit organization',
#   'bio': 'Human-centered AI research at Stanford University'},
#  {'username': 'DeepMind',
#   'no_of_posts': '2100',
#   'no_of_followers': '2800000',
#   'no_of_followings': '340',
#   'category': 'Software company',
#   'bio': 'Building AI responsibly for the long-term benefit of humanity'},
#  {'username': 'Meta AI',
#   'no_of_posts': '1870',
#   'no_of_followers': '3100000',
#   'no_of_followings': '520',
#   'category': 'Software company',
#   'bio': 'AI research and engineering at Meta'},
#  {'username': 'Google AI',
#   'no_of_posts': '3200',
#   'no_of_followers': '4500000',
#   'no_of_followings': '780',
#   'category': 'Software company',
#   'bio': 'Advancing AI for everyone at Google'},
#  {'username': 'Microsoft AI',
#   'no_of_posts': '2780',
#   'no_of_followers': '2200000',
#   'no_of_followings': '650',
#   'category': 'Software company',
#   'bio': 'AI products and research from Microsoft'},
#  {'username': 'IBM Research',
#   'no_of_posts': '4100',
#   'no_of_followers': '890000',
#   'no_of_followings': '1200',
#   'category': 'Software company',
#   'bio': 'Pioneering AI research since 1956'},
#  {'username': 'NVIDIA AI',
#   'no_of_posts': '1980',
#   'no_of_followers': '3400000',
#   'no_of_followings': '430',
#   'category': 'Software company',
#   'bio': 'Accelerating AI with GPU computing'},
#  {'username': 'Hugging Face',
#   'no_of_posts': '1560',
#   'no_of_followers': '2100000',
#   'no_of_followings': '980',
#   'category': 'Software company',
#   'bio': 'The AI community building the future of ML'},
#  {'username': 'Mistral AI',
#   'no_of_posts': '342',
#   'no_of_followers': '780000',
#   'no_of_followings': '210',
#   'category': 'Software company',
#   'bio': 'Frontier AI built in Europe, open and efficient'},
#  {'username': 'Anthropic',
#   'no_of_posts': '567',
#   'no_of_followers': '1200000',
#   'no_of_followings': '340',
#   'category': 'Software company',
#   'bio': 'AI safety company, makers of Claude'},
#  {'username': 'Stability AI',
#   'no_of_posts': '890',
#   'no_of_followers': '650000',
#   'no_of_followings': '420',
#   'category': 'Software company',
#   'bio': "Activating humanity's potential through AI"},
#  {'username': 'Cohere',
#   'no_of_posts': '423',
#   'no_of_followers': '290000',
#   'no_of_followings': '310',
#   'category': 'Software company',
#   'bio': 'AI for the enterprise, making NLP accessible'},
#  {'username': 'AI21 Labs',
#   'no_of_posts': '312',
#   'no_of_followers': '180000',
#   'no_of_followings': '270',
#   'category': 'Software company',
#   'bio': 'Building AI systems that understand and generate language'},
#  {'username': 'Inflection AI',
#   'no_of_posts': '156',
#   'no_of_followers': '320000',
#   'no_of_followings': '190',
#   'category': 'Software company',
#   'bio': 'Building AI for personal use'},
#  {'username': 'Adept AI',
#   'no_of_posts': '234',
#   'no_of_followers': '140000',
#   'no_of_followings': '230',
#   'category': 'Software company',
#   'bio': 'AI that takes actions, not just generates text'},
#  {'username': 'xAI',
#   'no_of_posts': '678',
#   'no_of_followers': '980000',
#   'no_of_followings': '420',
#   'category': 'Software company',
#   'bio': 'Understanding the universe with AI, founded by Elon Musk'},
#  {'username': 'Perplexity AI',
#   'no_of_posts': '456',
#   'no_of_followers': '870000',
#   'no_of_followings': '380',
#   'category': 'Software company',
#   'bio': 'AI-powered search and answer engine'},
#  {'username': 'Midjourney',
#   'no_of_posts': '2340',
#   'no_of_followers': '4800000',
#   'no_of_followings': '320',
#   'category': 'Digital creator',
#   'bio': 'An independent AI research lab exploring new mediums'},
#  {'username': 'Runway ML',
#   'no_of_posts': '1120',
#   'no_of_followers': '1900000',
#   'no_of_followings': '540',
#   'category': 'Software company',
#   'bio': 'AI-powered creative tools for video and images'},
#  {'username': 'ElevenLabs',
#   'no_of_posts': '876',
#   'no_of_followers': '1100000',
#   'no_of_followings': '380',
#   'category': 'Software company',
#   'bio': 'AI voice technology for everyone'},
#  {'username': 'AI Safety Institute',
#   'no_of_posts': '234',
#   'no_of_followers': '180000',
#   'no_of_followings': '290',
#   'category': 'Non-profit organization',
#   'bio': 'UK government institute for AI safety research'},
#  {'username': 'Partnership on AI',
#   'no_of_posts': '312',
#   'no_of_followers': '120000',
#   'no_of_followings': '340',
#   'category': 'Non-profit organization',
#   'bio': 'Multi-stakeholder org for responsible AI development'},
#  {'username': 'Center for AI Safety',
#   'no_of_posts': '189',
#   'no_of_followers': '230000',
#   'no_of_followings': '210',
#   'category': 'Non-profit organization',
#   'bio': 'Reducing societal-scale risks from AI'},
#  {'username': 'Future of Life Institute',
#   'no_of_posts': '423',
#   'no_of_followers': '340000',
#   'no_of_followings': '560',
#   'category': 'Non-profit organization',
#   'bio': 'Steering transformative technology towards a good future'},
#  {'username': 'ML Street Talk',
#   'no_of_posts': '678',
#   'no_of_followers': '430000',
#   'no_of_followings': '890',
#   'category': 'Digital creator',
#   'bio': 'Deep ML research discussions and interviews'},
#  {'username': 'Yannick Kilcher',
#   'no_of_posts': '890',
#   'no_of_followers': '620000',
#   'no_of_followings': '340',
#   'category': 'Digital creator',
#   'bio': 'ML researcher and YouTube educator'},
#  {'username': 'Two Minute Papers',
#   'no_of_posts': '1340',
#   'no_of_followers': '2100000',
#   'no_of_followings': '450',
#   'category': 'Digital creator',
#   'bio': 'Amazing AI research in bite-sized videos'},
#  {'username': 'AI Breakdown',
#   'no_of_posts': '567',
#   'no_of_followers': '780000',
#   'no_of_followings': '320',
#   'category': 'Digital creator',
#   'bio': 'Daily AI news and research explained simply'},
#  {'username': 'Harrison Kinsley',
#   'no_of_posts': '1230',
#   'no_of_followers': '890000',
#   'no_of_followings': '670',
#   'category': 'Digital creator',
#   'bio': 'Python and AI programming tutorials'},
#  {'username': 'Codebasics',
#   'no_of_posts': '2100',
#   'no_of_followers': '1400000',
#   'no_of_followings': '780',
#   'category': 'Education',
#   'bio': 'Data science and ML tutorials in plain language'},
#  {'username': 'Krish Naik',
#   'no_of_posts': '3400',
#   'no_of_followers': '2300000',
#   'no_of_followings': '1100',
#   'category': 'Education',
#   'bio': 'Chief Data Scientist, ML and AI educator'},
#  {'username': 'CampusX',
#   'no_of_posts': '1560',
#   'no_of_followers': '890000',
#   'no_of_followings': '670',
#   'category': 'Education',
#   'bio': 'Hindi-language data science and AI education'},
#  {'username': 'Data Science Dojo',
#   'no_of_posts': '2340',
#   'no_of_followers': '1200000',
#   'no_of_followings': '890',
#   'category': 'Education',
#   'bio': 'Data science training and community'},
#  {'username': 'Kaggle',
#   'no_of_posts': '1890',
#   'no_of_followers': '3400000',
#   'no_of_followings': '560',
#   'category': 'Education',
#   'bio': "World's largest data science and ML community"},
#  {'username': 'Towards Data Science',
#   'no_of_posts': '4500',
#   'no_of_followers': '2800000',
#   'no_of_followings': '1200',
#   'category': 'Digital creator',
#   'bio': 'Sharing concepts, ideas, and codes on data science'},
#  {'username': 'Analytics Vidhya',
#   'no_of_posts': '3210',
#   'no_of_followers': '1800000',
#   'no_of_followings': '980',
#   'category': 'Education',
#   'bio': "India's largest data science learning platform"},
#  {'username': 'fast.ai',
#   'no_of_posts': '678',
#   'no_of_followers': '980000',
#   'no_of_followings': '340',
#   'category': 'Education',
#   'bio': 'Making deep learning accessible to everyone'},
#  {'username': 'DeepLearning.AI',
#   'no_of_posts': '1230',
#   'no_of_followers': '2100000',
#   'no_of_followings': '560',
#   'category': 'Education',
#   'bio': 'World-class AI education by Andrew Ng'},
#  {'username': 'Elon Musk',
#   'no_of_posts': '1870',
#   'no_of_followers': '190000000',
#   'no_of_followings': '450',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Tesla, SpaceX, xAI; owner of X'},
#  {'username': 'Bill Gates',
#   'no_of_posts': '1560',
#   'no_of_followers': '78000000',
#   'no_of_followings': '230',
#   'category': 'Person of public figure',
#   'bio': 'Co-founder of Microsoft, philanthropist'},
#  {'username': 'Jeff Bezos',
#   'no_of_posts': '234',
#   'no_of_followers': '3200000',
#   'no_of_followings': '180',
#   'category': 'Person of public figure',
#   'bio': 'Founder of Amazon and Blue Origin'},
#  {'username': 'Sundar Pichai',
#   'no_of_posts': '678',
#   'no_of_followers': '7800000',
#   'no_of_followings': '320',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Google and Alphabet'},
#  {'username': 'Satya Nadella',
#   'no_of_posts': '890',
#   'no_of_followers': '5600000',
#   'no_of_followings': '450',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Microsoft, cloud and AI visionary'},
#  {'username': 'Tim Cook',
#   'no_of_posts': '345',
#   'no_of_followers': '14000000',
#   'no_of_followings': '270',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Apple, privacy advocate'},
#  {'username': 'Mark Zuckerberg',
#   'no_of_posts': '1230',
#   'no_of_followers': '12000000',
#   'no_of_followings': '380',
#   'category': 'Person of public figure',
#   'bio': 'CEO of Meta, building the metaverse and AI'},
#  {'username': 'NVIDIA',
#   'no_of_posts': '5600',
#   'no_of_followers': '20000000',
#   'no_of_followings': '890',
#   'category': 'Software company',
#   'bio': 'Powering the AI revolution with GPUs'},
#  {'username': 'Apple',
#   'no_of_posts': '1230',
#   'no_of_followers': '34000000',
#   'no_of_followings': '340',
#   'category': 'Electronics company',
#   'bio': 'Think different. Designed by Apple in California'},
#  {'username': 'Microsoft',
#   'no_of_posts': '4500',
#   'no_of_followers': '15000000',
#   'no_of_followings': '780',
#   'category': 'Software company',
#   'bio': 'Empowering every person and organization on the planet'},
#  {'username': 'Google',
#   'no_of_posts': '6700',
#   'no_of_followers': '28000000',
#   'no_of_followings': '1100',
#   'category': 'Software company',
#   'bio': "Organizing the world's information and making it useful"},
#  {'username': 'Amazon',
#   'no_of_posts': '3400',
#   'no_of_followers': '17000000',
#   'no_of_followings': '650',
#   'category': 'E-commerce company',
#   'bio': 'Work hard. Have fun. Make history'},
#  {'username': 'Tesla',
#   'no_of_posts': '2340',
#   'no_of_followers': '19000000',
#   'no_of_followings': '230',
#   'category': 'Automotive company',
#   'bio': "Accelerating the world's transition to sustainable energy"},
#  {'username': 'SpaceX',
#   'no_of_posts': '1120',
#   'no_of_followers': '9800000',
#   'no_of_followings': '180',
#   'category': 'Aerospace company',
#   'bio': 'Making life multiplanetary'},
#  {'username': 'WIRED',
#   'no_of_posts': '12000',
#   'no_of_followers': '4500000',
#   'no_of_followings': '2300',
#   'category': 'Magazine',
#   'bio': 'WIRED is where tomorrow is realized'},
#  {'username': 'TechCrunch',
#   'no_of_posts': '18000',
#   'no_of_followers': '5600000',
#   'no_of_followings': '3400',
#   'category': 'Magazine',
#   'bio': 'Startup and technology news'},
#  {'username': 'The Verge',
#   'no_of_posts': '21000',
#   'no_of_followers': '6800000',
#   'no_of_followings': '4500',
#   'category': 'Magazine',
#   'bio': 'Science, technology, art, and culture'},
#  {'username': 'MIT Technology Review',
#   'no_of_posts': '9800',
#   'no_of_followers': '3200000',
#   'no_of_followings': '1800',
#   'category': 'Magazine',
#   'bio': "Technology coverage from the world's oldest tech publication"},
#  {'username': 'Nature',
#   'no_of_posts': '23000',
#   'no_of_followers': '8900000',
#   'no_of_followings': '2100',
#   'category': 'Magazine',
#   'bio': 'International weekly journal of science'},
#  {'username': 'Science Magazine',
#   'no_of_posts': '18700',
#   'no_of_followers': '7200000',
#   'no_of_followings': '1900',
#   'category': 'Magazine',
#   'bio': 'Advancing science, serving society'},
#  {'username': 'IEEE Spectrum',
#   'no_of_posts': '8900',
#   'no_of_followers': '2100000',
#   'no_of_followings': '1600',
#   'category': 'Non-profit organization',
#   'bio': 'Technology, engineering, and science news from IEEE'},
#  {'username': 'ACM',
#   'no_of_posts': '5600',
#   'no_of_followers': '890000',
#   'no_of_followings': '1200',
#   'category': 'Non-profit organization',
#   'bio': 'Association for Computing Machinery'},
#  {'username': 'NeurIPS',
#   'no_of_posts': '1230',
#   'no_of_followers': '780000',
#   'no_of_followings': '340',
#   'category': 'Non-profit organization',
#   'bio': 'Neural Information Processing Systems conference'},
#  {'username': 'ICLR',
#   'no_of_posts': '890',
#   'no_of_followers': '560000',
#   'no_of_followings': '290',
#   'category': 'Non-profit organization',
#   'bio': 'International Conference on Learning Representations'},
#  {'username': 'ICML',
#   'no_of_posts': '1120',
#   'no_of_followers': '670000',
#   'no_of_followings': '310',
#   'category': 'Non-profit organization',
#   'bio': 'International Conference on Machine Learning'},
#  {'username': 'AAAI',
#   'no_of_posts': '1560',
#   'no_of_followers': '430000',
#   'no_of_followings': '380',
#   'category': 'Non-profit organization',
#   'bio': 'Association for the Advancement of Artificial Intelligence'},
#  {'username': 'CMU AI',
#   'no_of_posts': '2340',
#   'no_of_followers': '890000',
#   'no_of_followings': '560',
#   'category': 'Education',
#   'bio': 'AI research at Carnegie Mellon University'},
#  {'username': 'Berkeley AI Research',
#   'no_of_posts': '1890',
#   'no_of_followers': '1200000',
#   'no_of_followings': '490',
#   'category': 'Education',
#   'bio': 'BAIR — advancing AI research at UC Berkeley'},
#  {'username': 'Oxford Internet Institute',
#   'no_of_posts': '1120',
#   'no_of_followers': '670000',
#   'no_of_followings': '430',
#   'category': 'Education',
#   'bio': 'Multidisciplinary research on the internet and society'},
#  {'username': 'Cambridge AI Group',
#   'no_of_posts': '890',
#   'no_of_followers': '540000',
#   'no_of_followings': '370',
#   'category': 'Education',
#   'bio': 'AI research at the University of Cambridge'},
#  {'username': 'ETH Zurich',
#   'no_of_posts': '1560',
#   'no_of_followers': '2300000',
#   'no_of_followings': '670',
#   'category': 'Education',
#   'bio': 'Where innovation meets excellence in science and tech'},
#  {'username': 'Vector Institute',
#   'no_of_posts': '678',
#   'no_of_followers': '340000',
#   'no_of_followings': '290',
#   'category': 'Education',
#   'bio': 'AI research institute in Toronto, Canada'},
#  {'username': 'Mila Quebec AI',
#   'no_of_posts': '1230',
#   'no_of_followers': '560000',
#   'no_of_followings': '380',
#   'category': 'Non-profit organization',
#   'bio': 'World-leading AI research in Montreal'},
#  {'username': 'Alan Turing Institute',
#   'no_of_posts': '890',
#   'no_of_followers': '430000',
#   'no_of_followings': '320',
#   'category': 'Non-profit organization',
#   'bio': "UK's national institute for data science and AI"},
#  {'username': 'EleutherAI',
#   'no_of_posts': '456',
#   'no_of_followers': '780000',
#   'no_of_followings': '340',
#   'category': 'Non-profit organization',
#   'bio': 'Open-source AI research collective'},
#  {'username': 'LAION',
#   'no_of_posts': '234',
#   'no_of_followers': '230000',
#   'no_of_followings': '210',
#   'category': 'Non-profit organization',
#   'bio': 'Large-scale open datasets for AI research'},
#  {'username': 'Together AI',
#   'no_of_posts': '289',
#   'no_of_followers': '340000',
#   'no_of_followings': '270',
#   'category': 'Software company',
#   'bio': 'Fast and scalable open-source AI infrastructure'},
#  {'username': 'Modal Labs',
#   'no_of_posts': '178',
#   'no_of_followers': '210000',
#   'no_of_followings': '190',
#   'category': 'Software company',
#   'bio': 'Cloud computing for AI applications'},
#  {'username': 'Replicate',
#   'no_of_posts': '567',
#   'no_of_followers': '780000',
#   'no_of_followings': '380',
#   'category': 'Software company',
#   'bio': 'Run AI models in the cloud with one line of code'},
#  {'username': 'Gradio',
#   'no_of_posts': '345',
#   'no_of_followers': '560000',
#   'no_of_followings': '310',
#   'category': 'Software company',
#   'bio': 'Build and share ML demos in Python'},
#  {'username': 'OpenRouter',
#   'no_of_posts': '189',
#   'no_of_followers': '230000',
#   'no_of_followings': '450',
#   'category': 'Software company',
#   'bio': 'Unified API for hundreds of AI models'},
#  {'username': 'Civitai',
#   'no_of_posts': '1230',
#   'no_of_followers': '560000',
#   'no_of_followings': '670',
#   'category': 'Digital creator',
#   'bio': 'Community hub for AI-generated art and models'},
#  {'username': 'Abacus AI',
#   'no_of_posts': '345',
#   'no_of_followers': '290000',
#   'no_of_followings': '230',
#   'category': 'Software company',
#   'bio': 'Enterprise AI and ML platform'},
#  {'username': 'Tomek Korbak',
#   'no_of_posts': '89',
#   'no_of_followers': '34000',
#   'no_of_followings': '230',
#   'category': 'Scientist',
#   'bio': 'AI safety researcher at Anthropic'},
#  {'username': 'Nathan Lambert',
#   'no_of_posts': '123',
#   'no_of_followers': '89000',
#   'no_of_followings': '340',
#   'category': 'Scientist',
#   'bio': 'AI researcher, formerly at HuggingFace and Allen AI'},
#  {'username': 'Colin Wolfe',
#   'no_of_posts': '67',
#   'no_of_followers': '23000',
#   'no_of_followings': '180',
#   'category': 'Scientist',
#   'bio': 'NLP and AI alignment researcher'}]
