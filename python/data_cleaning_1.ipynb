# %%
import json

# %%
# function for loading data 
def load_json_data(filename):
    with open(filename ,"r") as f:
        data =json.load(f)
    return data

# %%
#function for cleaning the data
def cleaned_data(data):
    #removing users with missing values
    data["users"] = [user for user in data["users"] if user["name"].strip() ]

    #remove duplicates friends from user friends
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))
        
    #remove inactive users
    data["users"] = [user for user in data["users"] if user["friends"] or user["liked_pages"] ]

    #remove duplicate pages
    unique_pages = {}
    for page in data["pages"]:
        unique_pages[page["id"]] = page
    data["pages"] = list(unique_pages.values())
        
    return data

# %%
data = load_json_data("data2.json")
data = cleaned_data(data)
json.dump(data, open("cleaned_data_2.json" ,"w") , indent=4 )
print("data is successfully cleaned ")
# Out:
# data is successfully cleaned
