# %%
import pandas as pd

# %%
df = pd.read_csv("regional_sales_raw.csv")

# %%
df
# Out:
#     txn_id    store     category        item    qty  unit_price    txn_date  \
# 0     5001  Store A  Electronics  Headphones    2.0        1499  2023-11-01
# 1     5002  store b      Grocery    Rice 5kg    1.0         650  2023-11-01
# 2     5003  Store A  electronics     Charger    3.0         499  01/11/2023
# 3     5004  Store C     Clothing     T-Shirt    NaN         799  2023-11-02
# 4     5005  Store B      Grocery    Rice 5kg    1.0         650  2023-11-02
# 5     5006  Store A  Electronics  Headphones    2.0        1499  2023-11-01
# 6     5007  Store D     clothing       Jeans    1.0        1999  2023-11-03
# 7     5008  Store C      Grocery   Sugar 1kg    4.0          45  2023-11-03
# 8     5009  store a  Electronics       Mouse    2.0         399  03-11-2023
# 9     5010  Store B     Clothing     T-Shirt    5.0         799  2023-11-04
# 10    5011  Store D      Grocery   Sugar 1kg    NaN          45  2023-11-04
# 11    5012  Store C  Electronics     Charger    1.0         499  2023-11-05
# 12    5013  Store A     Clothing       Jeans    2.0        1999  2023-11-05
# 13    5014  Store B      Grocery    Rice 5kg    1.0         650  2023-11-02
# 14    5015  Store D  Electronics       Mouse   10.0         399  2023-11-06
# 15    5016  Store C     clothing     T-Shirt    3.0         799     invalid
# 16    5017  Store A      Grocery   Sugar 1kg    2.0         -45  2023-11-07
# 17    5018  Store B  Electronics  Headphones    1.0        1499  2023-11-07
# 18    5019  Store D     Clothing       Jeans  999.0        1999  2023-11-08
# 19    5020  store c      Grocery    Rice 5kg    2.0         650  2023-11-08
#
#    payment_method  customer_age  rating
# 0            Card          28.0     4.5
# 1            cash          45.0     NaN
# 2            Card           NaN     3.8
# 3             UPI          31.0     4.0
# 4            Cash          45.0     4.2
# 5            Card          28.0     4.5
# 6            card          -5.0     3.0
# 7             UPI          52.0     4.6
# 8            Cash           NaN     NaN
# 9            Card          29.0     4.9
# 10            upi          60.0     4.1
# 11           Card         150.0     3.5
# 12           Cash          33.0     NaN
# 13           Cash          45.0     4.2
# 14           card          41.0     4.4
# 15            UPI          26.0     4.3
# 16           Cash          38.0     4.0
# 17           Card           NaN     4.7
# 18            upi          47.0     3.9
# 19           cash          55.0     4.2

# %%
df["rating"] = df["rating"].fillna(0)

# %%
df["customer_age"] = df["customer_age"].fillna(df["customer_age"].mean())

# %%
df = df.dropna()

# %%
df
# Out:
#     txn_id    store     category        item    qty  unit_price    txn_date  \
# 0     5001  Store A  Electronics  Headphones    2.0        1499  2023-11-01
# 1     5002  store b      Grocery    Rice 5kg    1.0         650  2023-11-01
# 2     5003  Store A  electronics     Charger    3.0         499  01/11/2023
# 4     5005  Store B      Grocery    Rice 5kg    1.0         650  2023-11-02
# 5     5006  Store A  Electronics  Headphones    2.0        1499  2023-11-01
# 6     5007  Store D     clothing       Jeans    1.0        1999  2023-11-03
# 7     5008  Store C      Grocery   Sugar 1kg    4.0          45  2023-11-03
# 8     5009  store a  Electronics       Mouse    2.0         399  03-11-2023
# 9     5010  Store B     Clothing     T-Shirt    5.0         799  2023-11-04
# 11    5012  Store C  Electronics     Charger    1.0         499  2023-11-05
# 12    5013  Store A     Clothing       Jeans    2.0        1999  2023-11-05
# 13    5014  Store B      Grocery    Rice 5kg    1.0         650  2023-11-02
# 14    5015  Store D  Electronics       Mouse   10.0         399  2023-11-06
# 15    5016  Store C     clothing     T-Shirt    3.0         799     invalid
# 16    5017  Store A      Grocery   Sugar 1kg    2.0         -45  2023-11-07
# 17    5018  Store B  Electronics  Headphones    1.0        1499  2023-11-07
# 18    5019  Store D     Clothing       Jeans  999.0        1999  2023-11-08
# 19    5020  store c      Grocery    Rice 5kg    2.0         650  2023-11-08
#
#    payment_method  customer_age  rating
# 0            Card          28.0     4.5
# 1            cash          45.0     0.0
# 2            Card          44.0     3.8
# 4            Cash          45.0     4.2
# 5            Card          28.0     4.5
# 6            card          -5.0     3.0
# 7             UPI          52.0     4.6
# 8            Cash          44.0     0.0
# 9            Card          29.0     4.9
# 11           Card         150.0     3.5
# 12           Cash          33.0     0.0
# 13           Cash          45.0     4.2
# 14           card          41.0     4.4
# 15            UPI          26.0     4.3
# 16           Cash          38.0     4.0
# 17           Card          44.0     4.7
# 18            upi          47.0     3.9
# 19           cash          55.0     4.2

# %%
df
# Out:
#     txn_id    store     category        item    qty  unit_price    txn_date  \
# 0     5001  store a  Electronics  Headphones    2.0        1499  2023-11-01
# 1     5002  store b      Grocery    Rice 5kg    1.0         650  2023-11-01
# 2     5003  store a  electronics     Charger    3.0         499  01/11/2023
# 4     5005  store b      Grocery    Rice 5kg    1.0         650  2023-11-02
# 5     5006  store a  Electronics  Headphones    2.0        1499  2023-11-01
# 6     5007  store d     clothing       Jeans    1.0        1999  2023-11-03
# 7     5008  store c      Grocery   Sugar 1kg    4.0          45  2023-11-03
# 8     5009  store a  Electronics       Mouse    2.0         399  03-11-2023
# 9     5010  store b     Clothing     T-Shirt    5.0         799  2023-11-04
# 11    5012  store c  Electronics     Charger    1.0         499  2023-11-05
# 12    5013  store a     Clothing       Jeans    2.0        1999  2023-11-05
# 13    5014  store b      Grocery    Rice 5kg    1.0         650  2023-11-02
# 14    5015  store d  Electronics       Mouse   10.0         399  2023-11-06
# 15    5016  store c     clothing     T-Shirt    3.0         799     invalid
# 16    5017  store a      Grocery   Sugar 1kg    2.0         -45  2023-11-07
# 17    5018  store b  Electronics  Headphones    1.0        1499  2023-11-07
# 18    5019  store d     Clothing       Jeans  999.0        1999  2023-11-08
# 19    5020  store c      Grocery    Rice 5kg    2.0         650  2023-11-08
#
#    payment_method  customer_age  rating
# 0            Card          28.0     4.5
# 1            cash          45.0     0.0
# 2            Card          44.0     3.8
# 4            Cash          45.0     4.2
# 5            Card          28.0     4.5
# 6            card          -5.0     3.0
# 7             UPI          52.0     4.6
# 8            Cash          44.0     0.0
# 9            Card          29.0     4.9
# 11           Card         150.0     3.5
# 12           Cash          33.0     0.0
# 13           Cash          45.0     4.2
# 14           card          41.0     4.4
# 15            UPI          26.0     4.3
# 16           Cash          38.0     4.0
# 17           Card          44.0     4.7
# 18            upi          47.0     3.9
# 19           cash          55.0     4.2

# %%
df["category"] = df["category"].str.strip().str.lower()
# Out:
# /var/folders/yg/v2xb54j57hv9plgd_h_vzdzr0000gn/T/ipykernel_8773/3826901481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["category"] = df["category"].str.strip().str.lower()

# %%
df["payment_method"] = df["payment_method"].str.strip().str.lower()
# Out:
# /var/folders/yg/v2xb54j57hv9plgd_h_vzdzr0000gn/T/ipykernel_8773/2498522269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["payment_method"] = df["payment_method"].str.strip().str.lower()

# %%
df
# Out:
#     txn_id    store     category        item    qty  unit_price    txn_date  \
# 0     5001  store a  electronics  Headphones    2.0        1499  2023-11-01
# 1     5002  store b      grocery    Rice 5kg    1.0         650  2023-11-01
# 2     5003  store a  electronics     Charger    3.0         499  01/11/2023
# 4     5005  store b      grocery    Rice 5kg    1.0         650  2023-11-02
# 5     5006  store a  electronics  Headphones    2.0        1499  2023-11-01
# 6     5007  store d     clothing       Jeans    1.0        1999  2023-11-03
# 7     5008  store c      grocery   Sugar 1kg    4.0          45  2023-11-03
# 8     5009  store a  electronics       Mouse    2.0         399  03-11-2023
# 9     5010  store b     clothing     T-Shirt    5.0         799  2023-11-04
# 11    5012  store c  electronics     Charger    1.0         499  2023-11-05
# 12    5013  store a     clothing       Jeans    2.0        1999  2023-11-05
# 13    5014  store b      grocery    Rice 5kg    1.0         650  2023-11-02
# 14    5015  store d  electronics       Mouse   10.0         399  2023-11-06
# 15    5016  store c     clothing     T-Shirt    3.0         799     invalid
# 16    5017  store a      grocery   Sugar 1kg    2.0         -45  2023-11-07
# 17    5018  store b  electronics  Headphones    1.0        1499  2023-11-07
# 18    5019  store d     clothing       Jeans  999.0        1999  2023-11-08
# 19    5020  store c      grocery    Rice 5kg    2.0         650  2023-11-08
#
#    payment_method  customer_age  rating
# 0            card          28.0     4.5
# 1            cash          45.0     0.0
# 2            card          44.0     3.8
# 4            cash          45.0     4.2
# 5            card          28.0     4.5
# 6            card          -5.0     3.0
# 7             upi          52.0     4.6
# 8            cash          44.0     0.0
# 9            card          29.0     4.9
# 11           card         150.0     3.5
# 12           cash          33.0     0.0
# 13           cash          45.0     4.2
# 14           card          41.0     4.4
# 15            upi          26.0     4.3
# 16           cash          38.0     4.0
# 17           card          44.0     4.7
# 18            upi          47.0     3.9
# 19           cash          55.0     4.2
