# %%
import pandas as pd

# %%
df = pd.read_csv("sales_messy.csv")
df
# Out:
#     order_id      customer   product  quantity    price    order_date  \
# 0       1001    Ravi Kumar    Laptop       2.0  $450.00    04/01/2024
# 1       1002   Sneha Reddy     Mouse       5.0   $12.50    04/02/2024
# 2       1003     Amit Shah  Keyboard       NaN    25.00    2024-04-02
# 3       1004    Priya Nair    Laptop       1.0      450    04/03/2024
# 4       1005           NaN   Monitor       3.0   150.00    04/04/2024
# 5       1006    Vikram Rao     Mouse       2.0     12.5    04/04/2024
# 6       1007   Sneha Reddy     Mouse       5.0   $12.50    04/02/2024
# 7       1008   Anita Desai  Keyboard       4.0       25  invalid_date
# 8       1009   Rahul Verma    Laptop      -1.0   450.00    04/06/2024
# 9       1010  Kavita Joshi   Monitor       2.0  $150.00    04/07/2024
# 10      1011   Suresh Iyer     Mouse      10.0    12.50    04/08/2024
# 11      1012    Neha Gupta  Keyboard       3.0      NaN    04/09/2024
# ...

# %%
df["order_id"] #selecting a single column
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
# 5     1006
# 6     1007
# 7     1008
# 8     1009
# 9     1010
# 10    1011
# 11    1012
# 12    1013
# 13    1014
# 14    1015
# Name: order_id, dtype: int64

# %%
df[["order_id","customer","product"] ] #selecting multiple columns
# Out:
#     order_id      customer   product
# 0       1001    Ravi Kumar    Laptop
# 1       1002   Sneha Reddy     Mouse
# 2       1003     Amit Shah  Keyboard
# 3       1004    Priya Nair    Laptop
# 4       1005           NaN   Monitor
# 5       1006    Vikram Rao     Mouse
# 6       1007   Sneha Reddy     Mouse
# 7       1008   Anita Desai  Keyboard
# 8       1009   Rahul Verma    Laptop
# 9       1010  Kavita Joshi   Monitor
# 10      1011   Suresh Iyer     Mouse
# 11      1012    Neha Gupta  Keyboard
# 12      1013   Rahul Verma    Laptop
# 13      1014  Anjali Mehta   Monitor
# 14      1015  Deepak Singh     Mouse

# %%
df.loc[0 : 2] #selecting rows
# Out:
#    order_id     customer   product  quantity    price  order_date     status  \
# 0      1001   Ravi Kumar    Laptop       2.0  $450.00  04/01/2024  Delivered
# 1      1002  Sneha Reddy     Mouse       5.0   $12.50  04/02/2024  delivered
# 2      1003    Amit Shah  Keyboard       NaN    25.00  2024-04-02    Pending
#
#   region
# 0  South
# 1  North
# 2   east

# %%
df.loc[0:2,["order_id","customer","product"]]
# Out:
#    order_id     customer   product
# 0      1001   Ravi Kumar    Laptop
# 1      1002  Sneha Reddy     Mouse
# 2      1003    Amit Shah  Keyboard

# %%
df.iloc[0:3,0:3]
# Out:
#    order_id     customer   product
# 0      1001   Ravi Kumar    Laptop
# 1      1002  Sneha Reddy     Mouse
# 2      1003    Amit Shah  Keyboard

# %%
df.at[0,"customer"]
# Out:
# 'Ravi Kumar'

# %%
df.iat[0,1]
# Out:
# 'Ravi Kumar'

# %%
df
# Out:
#     order_id      customer   product  quantity    price    order_date  \
# 0       1001    Ravi Kumar    Laptop       2.0  $450.00    04/01/2024
# 1       1002   Sneha Reddy     Mouse       5.0   $12.50    04/02/2024
# 2       1003     Amit Shah  Keyboard       NaN    25.00    2024-04-02
# 3       1004    Priya Nair    Laptop       1.0      450    04/03/2024
# 4       1005           NaN   Monitor       3.0   150.00    04/04/2024
# 5       1006    Vikram Rao     Mouse       2.0     12.5    04/04/2024
# 6       1007   Sneha Reddy     Mouse       5.0   $12.50    04/02/2024
# 7       1008   Anita Desai  Keyboard       4.0       25  invalid_date
# 8       1009   Rahul Verma    Laptop      -1.0   450.00    04/06/2024
# 9       1010  Kavita Joshi   Monitor       2.0  $150.00    04/07/2024
# 10      1011   Suresh Iyer     Mouse      10.0    12.50    04/08/2024
# 11      1012    Neha Gupta  Keyboard       3.0      NaN    04/09/2024
# ...

# %%
df[ df["product"]=="Laptop" ]
# Out:
#     order_id     customer product  quantity    price  order_date     status  \
# 0       1001   Ravi Kumar  Laptop       2.0  $450.00  04/01/2024  Delivered
# 3       1004   Priya Nair  Laptop       1.0      450  04/03/2024  DELIVERED
# 8       1009  Rahul Verma  Laptop      -1.0   450.00  04/06/2024  Delivered
# 12      1013  Rahul Verma  Laptop       1.0   450.00  04/06/2024  Delivered
#
#    region
# 0   South
# 3   South
# 8   south
# 12  South

# %%
df[ (df["product"]=="Laptop" )| (df["status"] == "Delivered") ]
# Out:
#     order_id      customer  product  quantity    price  order_date     status  \
# 0       1001    Ravi Kumar   Laptop       2.0  $450.00  04/01/2024  Delivered
# 3       1004    Priya Nair   Laptop       1.0      450  04/03/2024  DELIVERED
# 5       1006    Vikram Rao    Mouse       2.0     12.5  04/04/2024  Delivered
# 8       1009   Rahul Verma   Laptop      -1.0   450.00  04/06/2024  Delivered
# 10      1011   Suresh Iyer    Mouse      10.0    12.50  04/08/2024  Delivered
# 12      1013   Rahul Verma   Laptop       1.0   450.00  04/06/2024  Delivered
# 13      1014  Anjali Mehta  Monitor     999.0   150.00  04/10/2024  Delivered
#
#    region
# 0   South
# 3   South
# 5   North
# 8   south
# 10  North
# 12  South
# 13   west

# %%
df.query("product == 'Laptop'")
# Out:
#     order_id     customer product  quantity    price  order_date     status  \
# 0       1001   Ravi Kumar  Laptop       2.0  $450.00  04/01/2024  Delivered
# 3       1004   Priya Nair  Laptop       1.0      450  04/03/2024  DELIVERED
# 8       1009  Rahul Verma  Laptop      -1.0   450.00  04/06/2024  Delivered
# 12      1013  Rahul Verma  Laptop       1.0   450.00  04/06/2024  Delivered
#
#    region
# 0   South
# 3   South
# 8   south
# 12  South

# %%
df.query("status=='Delivered'")
# Out:
#     order_id      customer  product  quantity    price  order_date     status  \
# 0       1001    Ravi Kumar   Laptop       2.0  $450.00  04/01/2024  Delivered
# 5       1006    Vikram Rao    Mouse       2.0     12.5  04/04/2024  Delivered
# 8       1009   Rahul Verma   Laptop      -1.0   450.00  04/06/2024  Delivered
# 10      1011   Suresh Iyer    Mouse      10.0    12.50  04/08/2024  Delivered
# 12      1013   Rahul Verma   Laptop       1.0   450.00  04/06/2024  Delivered
# 13      1014  Anjali Mehta  Monitor     999.0   150.00  04/10/2024  Delivered
#
#    region
# 0   South
# 5   North
# 8   south
# 10  North
# 12  South
# 13   west

# %%
df.query("product == 'Laptop' and status == 'Delivered' ")
# Out:
#     order_id     customer product  quantity    price  order_date     status  \
# 0       1001   Ravi Kumar  Laptop       2.0  $450.00  04/01/2024  Delivered
# 8       1009  Rahul Verma  Laptop      -1.0   450.00  04/06/2024  Delivered
# 12      1013  Rahul Verma  Laptop       1.0   450.00  04/06/2024  Delivered
#
#    region
# 0   South
# 8   south
# 12  South
