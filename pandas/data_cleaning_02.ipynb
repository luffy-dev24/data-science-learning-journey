# %%
import pandas as pd

# %%
df = pd.read_csv("1_missing_values.csv")
df
# Out:
#    student_id    name  subject  score  attendance
# 0           1   Aarav     Math   78.0        92.0
# 1           2    Diya  Science    NaN        88.0
# 2           3   Kabir     Math   65.0         NaN
# 3           4   Meera  English    NaN        79.0
# 4           5   Rohan  Science   54.0        95.0
# 5           6    Isha     Math    NaN         NaN
# 6           7  Aditya  English   88.0        84.0
# 7           8   Priya  Science   90.0         NaN
# 8           9  Vivaan     Math   72.0        90.0
# 9          10    Sara  English    NaN        81.0

# %%
df.isnull().sum() #checking missing values
# Out:
# student_id    0
# name          0
# subject       0
# score         4
# attendance    3
# dtype: int64

# %%
df_cleaned_score = df.dropna(subset=["score","attendance"])

# %%
df_cleaned_attendance = df.dropna(subset=["attendance"])

# %%
df_cleaned_score
# Out:
#    student_id    name  subject  score  attendance
# 0           1   Aarav     Math   78.0        92.0
# 4           5   Rohan  Science   54.0        95.0
# 6           7  Aditya  English   88.0        84.0
# 8           9  Vivaan     Math   72.0        90.0

# %%
df
# Out:
#    student_id    name  subject  score  attendance
# 0           1   Aarav     Math   78.0        92.0
# 1           2    Diya  Science    NaN        88.0
# 2           3   Kabir     Math   65.0         NaN
# 3           4   Meera  English    NaN        79.0
# 4           5   Rohan  Science   54.0        95.0
# 5           6    Isha     Math    NaN         NaN
# 6           7  Aditya  English   88.0        84.0
# 7           8   Priya  Science   90.0         NaN
# 8           9  Vivaan     Math   72.0        90.0
# 9          10    Sara  English    NaN        81.0

# %%
df["attendance"] = df["attendance"].fillna(df["attendance"].mean())

# %%
df["score"] = df["score"].fillna(df["score"].mean())

# %%
df_ffill = df["score"].ffill()

# %%
df_ffill
# Out:
# 0    78.0
# 1    78.0
# 2    65.0
# 3    65.0
# 4    54.0
# 5    54.0
# 6    88.0
# 7    90.0
# 8    72.0
# 9    72.0
# Name: score, dtype: float64

# %%
df_bfill = df["score"].bfill()

# %%
df_bfill
# Out:
# 0    78.0
# 1    65.0
# 2    65.0
# 3    54.0
# 4    54.0
# 5    88.0
# 6    88.0
# 7    90.0
# 8    72.0
# 9     NaN
# Name: score, dtype: float64
